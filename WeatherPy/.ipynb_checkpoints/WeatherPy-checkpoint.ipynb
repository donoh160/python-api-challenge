# %% [markdown]
# # WeatherPy
#
# ## Before Submitting:
# - First Cell:
#     - Remove np.random.seed() when submitting
#     - Change size back from 200 to 1500
# - Add Analysis for each pair of graphs at bottom of notebook
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
np.random.seed(4227)

# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=200)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=200)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 125

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# base_url = f'https://api.openweathermap.org/data/3.0/onecall?'
api_key = weather_api_key 
units = 'metric'
base_url = "http://api.openweathermap.org/data/2.5/weather?"
# to add onto url: f'lat={lat}&lon={lon}&exclude={part}&appid={API key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    # city_url = base_url + f'lat={lat}&lon={lon}&exclude={part}&appid={API key}'
    # city_url = base_url + f'city={city}&appid={API key}'
    query_url = f"{base_url}appid={api_key}&q={city}&units={units}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(query_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | cabo san lucas
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | rabo de peixe
# Processing Record 5 of Set 1 | nar'yan-mar
# Processing Record 6 of Set 1 | wailua homesteads
# Processing Record 7 of Set 1 | san patricio
# Processing Record 8 of Set 1 | salahonda
# Processing Record 9 of Set 1 | nova sintra
# Processing Record 10 of Set 1 | papao
# Processing Record 11 of Set 1 | jashpurnagar
# Processing Record 12 of Set 1 | stanley
# Processing Record 13 of Set 1 | verkhovazh'ye
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | altai
# Processing Record 16 of Set 1 | iron river
# Processing Record 17 of Set 1 | al mijlad
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | sawston
# Processing Record 20 of Set 1 | kargat
# Processing Record 21 of Set 1 | linxia chengguanzhen
# Processing Record 22 of Set 1 | namibe
# Processing Record 23 of Set 1 | grytviken
# Processing Record 24 of Set 1 | sao joao da barra
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | grand rapids
# Processing Record 27 of Set 1 | cole harbour
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | balykshi
# Processing Record 31 of Set 1 | adamstown
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | blackmans bay
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | tindouf
# Processing Record 36 of Set 1 | west island
# Processing Record 37 of Set 1 | the pas
# Processing Record 38 of Set 1 | sishilichengzi
# City not found. Skipping...
# Processing Record 39 of Set 1 | ghardaia
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | celestun
# Processing Record 42 of Set 1 | puerto natales
# Processing Record 43 of Set 1 | kapuskasing
# Processing Record 44 of Set 1 | dudinka
# Processing Record 45 of Set 1 | runaway bay
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | olonkinbyen
# Processing Record 48 of Set 1 | antalaha
# Processing Record 49 of Set 1 | lihue
# Processing Record 50 of Set 1 | beloyarskiy
# Processing Record 0 of Set 2 | happy valley-goose bay
# Processing Record 1 of Set 2 | aberdeen
# Processing Record 2 of Set 2 | isafjordur
# Processing Record 3 of Set 2 | greenville
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | taltal
# Processing Record 6 of Set 2 | prince george
# Processing Record 7 of Set 2 | guarapari
# Processing Record 8 of Set 2 | ilulissat
# Processing Record 9 of Set 2 | mambajao
# Processing Record 10 of Set 2 | tahe
# Processing Record 11 of Set 2 | mastic beach
# Processing Record 12 of Set 2 | turpan
# Processing Record 13 of Set 2 | mount pearl
# Processing Record 14 of Set 2 | broken hill
# Processing Record 15 of Set 2 | franceville
# Processing Record 16 of Set 2 | whitehorse
# Processing Record 17 of Set 2 | sisimiut
# Processing Record 18 of Set 2 | laguna
# Processing Record 19 of Set 2 | kuqa
# Processing Record 20 of Set 2 | vorgashor
# Processing Record 21 of Set 2 | dunedin
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | basco
# Processing Record 24 of Set 2 | port lincoln
# Processing Record 25 of Set 2 | richards bay
# Processing Record 26 of Set 2 | lospalos
# Processing Record 27 of Set 2 | aasiaat
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | tual
# Processing Record 31 of Set 2 | ciudad cerralvo
# City not found. Skipping...
# Processing Record 32 of Set 2 | vila franca do campo
# Processing Record 33 of Set 2 | kununurra
# Processing Record 34 of Set 2 | ola
# Processing Record 35 of Set 2 | fortuna
# Processing Record 36 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 38 of Set 2 | wolmaransstad
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | flin flon
# Processing Record 42 of Set 2 | papatowai
# Processing Record 43 of Set 2 | uturoa
# Processing Record 44 of Set 2 | gueltat zemmour
# City not found. Skipping...
# Processing Record 45 of Set 2 | vadso
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | nouadhibou
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | qarauyl
# Processing Record 0 of Set 3 | tughyl
# Processing Record 1 of Set 3 | champerico
# Processing Record 2 of Set 3 | polyarnyy
# Processing Record 3 of Set 3 | waingapu
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | abadan
# Processing Record 6 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 7 of Set 3 | medicine hat
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | auki
# Processing Record 10 of Set 3 | agropoli
# Processing Record 11 of Set 3 | karoi
# Processing Record 12 of Set 3 | hawaiian paradise park
# Processing Record 13 of Set 3 | hammerfest
# Processing Record 14 of Set 3 | barah
# Processing Record 15 of Set 3 | ust-nera
# Processing Record 16 of Set 3 | gasa
# Processing Record 17 of Set 3 | alaghsas
# Processing Record 18 of Set 3 | isangel
# Processing Record 19 of Set 3 | ploneour-lanvern
# Processing Record 20 of Set 3 | jerantut
# Processing Record 21 of Set 3 | xiuyan
# Processing Record 22 of Set 3 | college
# Processing Record 23 of Set 3 | erraguntla
# Processing Record 24 of Set 3 | keflavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df =  pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          120
# Lat           120
# Lng           120
# Max Temp      120
# Humidity      120
# Cloudiness    120
# Wind Speed    120
# Country       120
# Date          120
# dtype: int64

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116     14.71        89
# 1                     cabo san lucas  22.8909 -109.9124     27.09        42
# 2                  port-aux-francais -49.3500   70.2167      3.58        70
# 3                      rabo de peixe  37.8000  -25.5833     17.77        99
# 4                        nar'yan-mar  67.6713   53.0870     -9.08        97
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                37        6.71      SH  1730932850
# 1                75        6.26      MX  1730932851
# 2                21        8.89      TF  1730932852
# 3                20        3.09      PT  1730932853
# 4                58        1.75      RU  1730932854

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

# x, y data
x_axis = city_data_df['Lat']
data = city_data_df['Max Temp']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")
plt.grid(True)

# Labels
plt.title("City Latitude vs Temperature (2024-11-06)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

# x, y data
x_axis = city_data_df['Lat']
data = city_data_df['Humidity']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")
plt.grid(True)

# Labels
plt.title("City Latitude vs Humidity (2024-11-06)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness

# x, y data
x_axis = city_data_df['Lat']
data = city_data_df['Cloudiness']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")
plt.grid(True)

# Labels
plt.title("City Latitude vs Cloudiness (2024-11-06)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

# x, y data
x_axis = city_data_df['Lat']
data = city_data_df['Wind Speed']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")
plt.grid(True)

# Labels
plt.title("City Latitude vs Cloudiness (2024-11-06)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def lin_reg(x, y):
    # Find slope and intercept of regression line, set linear
    b, a = np.polyfit(x, y, deg=1)
    
    # Plot regression line
    xseq = np.linspace(min(x), max(x))
    plt.plot(xseq, a + b * xseq, color="r")
    
    # Display reg line's equation
    line_eq = "y = " + str(round(b,2)) + "x + " + str(round(a,2))
    x_coord = min(x)
    y_coord = min(y)
    plt.annotate(line_eq,(x_coord, y_coord),fontsize=15,color="red")

    # Calculate and print correlation coefficient
    r = np.corrcoef(x, y)
    r_2 = '{0:.2f}'.format(r[0, 1]**2)
    print(f'The r^2-value is: {r_2}')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           cabo san lucas  22.8909 -109.9124     27.09        42          75
# 3            rabo de peixe  37.8000  -25.5833     17.77        99          20
# 4              nar'yan-mar  67.6713   53.0870     -9.08        97          58
# 5        wailua homesteads  22.0669 -159.3780     27.44        84          40
# 6             san patricio  28.0170  -97.5169     26.97        74          11
#
#          Wind Speed Country        Date
# City_ID
# 1              6.26      MX  1730932851
# 3              3.09      PT  1730932853
# 4              1.75      RU  1730932854
# 5              8.23      US  1730932856
# 6              3.90      US  1730932857

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116     14.71        89
# 2                  port-aux-francais -49.3500   70.2167      3.58        70
# 9                              papao -17.7500 -149.5500     28.82        76
# 13                          waitangi -43.9535 -176.5597     13.01        91
# 21                            namibe -15.1961   12.1522     19.99        85
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                37        6.71      SH  1730932850
# 2                21        8.89      TF  1730932852
# 9                21        5.34      PF  1730932860
# 13               83        2.91      NZ  1730932864
# 21               90        3.59      AO  1730932873

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# x,y data
lat_data = northern_hemi_df['Lat']
temp_data = northern_hemi_df['Max Temp']

# Create scatterplot
plt.scatter(lat_data, temp_data)

# Add regression line
lin_reg(lat_data, temp_data)

# Display Plot
plt.show()
# Out:
# The r^2-value is: 0.73

# %%
# Linear regression on Southern Hemisphere

# x,y data
lat_data = southern_hemi_df['Lat']
temp_data = southern_hemi_df['Max Temp']

# Create scatterplot
plt.scatter(lat_data, temp_data)

# Add regression line
lin_reg(lat_data, temp_data)

# Display Plot
plt.show()
# Out:
# The r^2-value is: 0.70

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# x, y data
x_axis = northern_hemi_df['Lat']
data = northern_hemi_df['Humidity']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")

# Labels
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Regression plots
lin_reg(x_axis, data)
        
plt.show()
# Out:
# The r^2-value is: 0.09

# %%
# Southern Hemisphere

# x, y data
x_axis = southern_hemi_df['Lat']
data = southern_hemi_df['Humidity']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")

# Labels
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Regression plots
lin_reg(x_axis, data)
        
plt.show()
# Out:
# The r^2-value is: 0.08

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# x, y data
x_axis = northern_hemi_df['Lat']
data = northern_hemi_df['Cloudiness']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")

# Labels
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Regression plots
lin_reg(x_axis, data)
        
plt.show()
# Out:
# The r^2-value is: 0.09

# %%
# Southern Hemisphere

# x, y data
x_axis = southern_hemi_df['Lat']
data = southern_hemi_df['Cloudiness']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")

# Labels
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Regression plots
lin_reg(x_axis, data)
        
plt.show()
# Out:
# The r^2-value is: 0.03

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# x, y data
x_axis = northern_hemi_df['Lat']
data = northern_hemi_df['Wind Speed']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")

# Labels
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Regression plots
lin_reg(x_axis, data)
        
plt.show()
# Out:
# The r^2-value is: 0.01

# %%
# Southern Hemisphere

# x, y data
x_axis = southern_hemi_df['Lat']
data = southern_hemi_df['Wind Speed']

# Create Scatterplot
plt.scatter(x_axis, data, s=40, edgecolors="black")

# Labels
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Regression plots
lin_reg(x_axis, data)
        
plt.show()
# Out:
# The r^2-value is: 0.12

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
